# %%
# !pip install llama-index transformers accelerate bitsandbytes pypdf
# Out:
# Collecting llama-index
#   Downloading llama_index-0.10.18-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: transformers in /home/edoardo/devel/env/lib/python3.10/site-packages (4.38.2)
# Requirement already satisfied: accelerate in /home/edoardo/devel/env/lib/python3.10/site-packages (0.27.2)
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.43.0-py3-none-manylinux_2_24_x86_64.whl.metadata (1.8 kB)
# Collecting pypdf
#   Downloading pypdf-4.1.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting llama-index-agent-openai<0.2.0,>=0.1.4 (from llama-index)
#   Downloading llama_index_agent_openai-0.1.5-py3-none-any.whl.metadata (695 bytes)
# Collecting llama-index-cli<0.2.0,>=0.1.2 (from llama-index)
#   Downloading llama_index_cli-0.1.8-py3-none-any.whl.metadata (1.6 kB)
# Collecting llama-index-core<0.11.0,>=0.10.18 (from llama-index)
#   Downloading llama_index_core-0.10.18.post1-py3-none-any.whl.metadata (3.6 kB)
# Collecting llama-index-embeddings-openai<0.2.0,>=0.1.5 (from llama-index)
#   Downloading llama_index_embeddings_openai-0.1.6-py3-none-any.whl.metadata (654 bytes)
# Collecting llama-index-indices-managed-llama-cloud<0.2.0,>=0.1.2 (from llama-index)
#   Downloading llama_index_indices_managed_llama_cloud-0.1.3-py3-none-any.whl.metadata (3.9 kB)
# Collecting llama-index-legacy<0.10.0,>=0.9.48 (from llama-index)
#   Downloading llama_index_legacy-0.9.48-py3-none-any.whl.metadata (8.5 kB)
# Collecting llama-index-llms-openai<0.2.0,>=0.1.5 (from llama-index)
#   Downloading llama_index_llms_openai-0.1.7-py3-none-any.whl.metadata (557 bytes)
# Collecting llama-index-multi-modal-llms-openai<0.2.0,>=0.1.3 (from llama-index)
#   Downloading llama_index_multi_modal_llms_openai-0.1.4-py3-none-any.whl.metadata (728 bytes)
# Collecting llama-index-program-openai<0.2.0,>=0.1.3 (from llama-index)
#   Downloading llama_index_program_openai-0.1.4-py3-none-any.whl.metadata (766 bytes)
# Collecting llama-index-question-gen-openai<0.2.0,>=0.1.2 (from llama-index)
#   Downloading llama_index_question_gen_openai-0.1.3-py3-none-any.whl.metadata (785 bytes)
# Collecting llama-index-readers-file<0.2.0,>=0.1.4 (from llama-index)
#   Downloading llama_index_readers_file-0.1.9-py3-none-any.whl.metadata (969 bytes)
# Collecting llama-index-readers-llama-parse<0.2.0,>=0.1.2 (from llama-index)
#   Downloading llama_index_readers_llama_parse-0.1.3-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: filelock in /home/edoardo/devel/env/lib/python3.10/site-packages (from transformers) (3.12.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /home/edoardo/devel/env/lib/python3.10/site-packages (from transformers) (0.21.3)
# Requirement already satisfied: numpy>=1.17 in /home/edoardo/devel/env/lib/python3.10/site-packages (from transformers) (1.23.0)
# Requirement already satisfied: packaging>=20.0 in /home/edoardo/devel/env/lib/python3.10/site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/edoardo/devel/env/lib/python3.10/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/edoardo/devel/env/lib/python3.10/site-packages (from transformers) (2023.10.3)
# Requirement already satisfied: requests in /home/edoardo/devel/env/lib/python3.10/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /home/edoardo/devel/env/lib/python3.10/site-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /home/edoardo/devel/env/lib/python3.10/site-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /home/edoardo/devel/env/lib/python3.10/site-packages (from transformers) (4.65.0)
# Requirement already satisfied: psutil in /home/edoardo/devel/env/lib/python3.10/site-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=1.10.0 in /home/edoardo/devel/env/lib/python3.10/site-packages (from accelerate) (2.0.1+cu118)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/edoardo/devel/env/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.9.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/edoardo/devel/env/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.10.0)
# Collecting llama-index-vector-stores-chroma<0.2.0,>=0.1.1 (from llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading llama_index_vector_stores_chroma-0.1.6-py3-none-any.whl.metadata (654 bytes)
# Collecting SQLAlchemy>=1.4.49 (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.18->llama-index)
#   Downloading SQLAlchemy-2.0.28-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /home/edoardo/devel/env/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.18->llama-index) (3.9.3)
# Requirement already satisfied: dataclasses-json in /home/edoardo/devel/env/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.18->llama-index) (0.6.0)
# Collecting deprecated>=1.2.9.3 (from llama-index-core<0.11.0,>=0.10.18->llama-index)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting dirtyjson<2.0.0,>=1.0.8 (from llama-index-core<0.11.0,>=0.10.18->llama-index)
#   Downloading dirtyjson-1.0.8-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: httpx in /home/edoardo/devel/env/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.18->llama-index) (0.25.0)
# Collecting llamaindex-py-client<0.2.0,>=0.1.13 (from llama-index-core<0.11.0,>=0.10.18->llama-index)
#   Downloading llamaindex_py_client-0.1.13-py3-none-any.whl.metadata (762 bytes)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /home/edoardo/devel/env/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.18->llama-index) (1.5.8)
# Collecting networkx>=3.0 (from llama-index-core<0.11.0,>=0.10.18->llama-index)
#   Downloading networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /home/edoardo/devel/env/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.18->llama-index) (3.8.1)
# Collecting openai>=1.1.0 (from llama-index-core<0.11.0,>=0.10.18->llama-index)
#   Downloading openai-1.13.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: pandas in /home/edoardo/devel/env/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.18->llama-index) (1.5.3)
# Requirement already satisfied: pillow>=9.0.0 in /home/edoardo/devel/env/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.18->llama-index) (9.5.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /home/edoardo/devel/env/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.18->llama-index) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in /home/edoardo/devel/env/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.18->llama-index) (0.5.1)
# Collecting tqdm>=4.27 (from transformers)
#   Downloading tqdm-4.66.2-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: typing-inspect>=0.8.0 in /home/edoardo/devel/env/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.18->llama-index) (0.9.0)
# Collecting beautifulsoup4<5.0.0,>=4.12.3 (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index)
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting bs4<0.0.3,>=0.0.2 (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index)
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Collecting pymupdf<2.0.0,>=1.23.21 (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index)
#   Downloading PyMuPDF-1.23.26-cp310-none-manylinux2014_x86_64.whl.metadata (3.4 kB)
# Collecting striprtf<0.0.27,>=0.0.26 (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index)
#   Downloading striprtf-0.0.26-py3-none-any.whl.metadata (2.1 kB)
# Collecting llama-parse<0.4.0,>=0.3.3 (from llama-index-readers-llama-parse<0.2.0,>=0.1.2->llama-index)
#   Downloading llama_parse-0.3.8-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/edoardo/devel/env/lib/python3.10/site-packages (from requests->transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/edoardo/devel/env/lib/python3.10/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/edoardo/devel/env/lib/python3.10/site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/edoardo/devel/env/lib/python3.10/site-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: sympy in /home/edoardo/devel/env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: jinja2 in /home/edoardo/devel/env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /home/edoardo/devel/env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (2.0.0)
# Requirement already satisfied: cmake in /home/edoardo/devel/env/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.10.0->accelerate) (3.28.3)
# Requirement already satisfied: lit in /home/edoardo/devel/env/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.10.0->accelerate) (17.0.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/edoardo/devel/env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.18->llama-index) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/edoardo/devel/env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.18->llama-index) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/edoardo/devel/env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.18->llama-index) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/edoardo/devel/env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.18->llama-index) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/edoardo/devel/env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.18->llama-index) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/edoardo/devel/env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.18->llama-index) (4.0.3)
# Requirement already satisfied: soupsieve>1.2 in /home/edoardo/devel/env/lib/python3.10/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (2.5)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/edoardo/devel/env/lib/python3.10/site-packages (from deprecated>=1.2.9.3->llama-index-core<0.11.0,>=0.10.18->llama-index) (1.15.0)
# Collecting chromadb<0.5.0,>=0.4.22 (from llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading chromadb-0.4.24-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pydantic>=1.10 in /home/edoardo/devel/env/lib/python3.10/site-packages (from llamaindex-py-client<0.2.0,>=0.1.13->llama-index-core<0.11.0,>=0.10.18->llama-index) (1.10.13)
# Requirement already satisfied: httpcore<0.19.0,>=0.18.0 in /home/edoardo/devel/env/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.18->llama-index) (0.18.0)
# Requirement already satisfied: sniffio in /home/edoardo/devel/env/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.18->llama-index) (1.3.0)
# Requirement already satisfied: click in /home/edoardo/devel/env/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.18->llama-index) (8.1.7)
# Requirement already satisfied: joblib in /home/edoardo/devel/env/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.18->llama-index) (1.3.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/edoardo/devel/env/lib/python3.10/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.18->llama-index) (4.0.0)
# Collecting distro<2,>=1.7.0 (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.18->llama-index)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting PyMuPDFb==1.23.22 (from pymupdf<2.0.0,>=1.23.21->llama-index-readers-file<0.2.0,>=0.1.4->llama-index)
#   Downloading PyMuPDFb-1.23.22-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.4 kB)
# Collecting greenlet!=0.4.17 (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.18->llama-index)
#   Downloading greenlet-3.0.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/edoardo/devel/env/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.18->llama-index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/edoardo/devel/env/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.18->llama-index) (3.20.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/edoardo/devel/env/lib/python3.10/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/edoardo/devel/env/lib/python3.10/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.18->llama-index) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/edoardo/devel/env/lib/python3.10/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.18->llama-index) (2023.3.post1)
# Requirement already satisfied: mpmath>=0.19 in /home/edoardo/devel/env/lib/python3.10/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/edoardo/devel/env/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai>=1.1.0->llama-index-core<0.11.0,>=0.10.18->llama-index) (1.1.3)
# Collecting build>=1.0.3 (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading build-1.1.1-py3-none-any.whl.metadata (4.2 kB)
# Collecting chroma-hnswlib==0.7.3 (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading chroma_hnswlib-0.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (252 bytes)
# Requirement already satisfied: fastapi>=0.95.2 in /home/edoardo/devel/env/lib/python3.10/site-packages (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index) (0.110.0)
# Requirement already satisfied: uvicorn>=0.18.3 in /home/edoardo/devel/env/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index) (0.27.1)
# Requirement already satisfied: posthog>=2.4.0 in /home/edoardo/devel/env/lib/python3.10/site-packages (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index) (3.0.2)
# Collecting pulsar-client>=3.1.0 (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading pulsar_client-3.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.0 kB)
# Requirement already satisfied: onnxruntime>=1.14.1 in /home/edoardo/devel/env/lib/python3.10/site-packages (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index) (1.17.1)
# Collecting opentelemetry-api>=1.2.0 (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading opentelemetry_api-1.23.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.23.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading opentelemetry_instrumentation_fastapi-0.44b0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading opentelemetry_sdk-1.23.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting pypika>=0.48.9 (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 9.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: overrides>=7.3.1 in /home/edoardo/devel/env/lib/python3.10/site-packages (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index) (7.4.0)
# Collecting importlib-resources (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading importlib_resources-6.1.3-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: grpcio>=1.58.0 in /home/edoardo/devel/env/lib/python3.10/site-packages (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index) (1.58.0)
# Collecting bcrypt>=4.0.1 (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading bcrypt-4.1.2-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Requirement already satisfied: typer>=0.9.0 in /home/edoardo/devel/env/lib/python3.10/site-packages (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index) (0.9.0)
# Collecting kubernetes>=28.1.0 (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading kubernetes-29.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting mmh3>=4.0.1 (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading mmh3-4.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: orjson>=3.9.12 in /home/edoardo/devel/env/lib/python3.10/site-packages (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index) (3.9.15)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/edoardo/devel/env/lib/python3.10/site-packages (from httpcore<0.19.0,>=0.18.0->httpx->llama-index-core<0.11.0,>=0.10.18->llama-index) (0.14.0)
# Requirement already satisfied: six>=1.5 in /home/edoardo/devel/env/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->llama-index-core<0.11.0,>=0.10.18->llama-index) (1.16.0)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading pyproject_hooks-1.0.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: tomli>=1.1.0 in /home/edoardo/devel/env/lib/python3.10/site-packages (from build>=1.0.3->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index) (2.0.1)
# Requirement already satisfied: starlette<0.37.0,>=0.36.3 in /home/edoardo/devel/env/lib/python3.10/site-packages (from fastapi>=0.95.2->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index) (0.36.3)
# Requirement already satisfied: google-auth>=1.0.1 in /home/edoardo/devel/env/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index) (2.23.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/edoardo/devel/env/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index) (1.6.3)
# Requirement already satisfied: requests-oauthlib in /home/edoardo/devel/env/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /home/edoardo/devel/env/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index) (3.2.2)
# Requirement already satisfied: coloredlogs in /home/edoardo/devel/env/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/edoardo/devel/env/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index) (23.5.26)
# Requirement already satisfied: protobuf in /home/edoardo/devel/env/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index) (3.20.3)
# Requirement already satisfied: importlib-metadata<7.0,>=6.0 in /home/edoardo/devel/env/lib/python3.10/site-packages (from opentelemetry-api>=1.2.0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index) (6.8.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /home/edoardo/devel/env/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index) (1.60.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.23.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.23.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting opentelemetry-proto==1.23.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading opentelemetry_proto-1.23.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-asgi==0.44b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading opentelemetry_instrumentation_asgi-0.44b0-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-instrumentation==0.44b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading opentelemetry_instrumentation-0.44b0-py3-none-any.whl.metadata (6.1 kB)
# Collecting opentelemetry-semantic-conventions==0.44b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading opentelemetry_semantic_conventions-0.44b0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-util-http==0.44b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading opentelemetry_util_http-0.44b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: setuptools>=16.0 in /home/edoardo/devel/env/lib/python3.10/site-packages (from opentelemetry-instrumentation==0.44b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index) (59.6.0)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.44b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading asgiref-3.7.2-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: monotonic>=1.5 in /home/edoardo/devel/env/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /home/edoardo/devel/env/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index) (2.2.1)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading watchfiles-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: websockets>=10.4 in /home/edoardo/devel/env/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index) (11.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/edoardo/devel/env/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/edoardo/devel/env/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/edoardo/devel/env/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index) (4.9)
# Requirement already satisfied: zipp>=0.5 in /home/edoardo/devel/env/lib/python3.10/site-packages (from importlib-metadata<7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index) (3.17.0)
# Requirement already satisfied: humanfriendly>=9.1 in /home/edoardo/devel/env/lib/python3.10/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index) (10.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/edoardo/devel/env/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index) (0.5.0)
# Downloading llama_index-0.10.18-py3-none-any.whl (5.6 kB)
# Downloading bitsandbytes-0.43.0-py3-none-manylinux_2_24_x86_64.whl (102.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 MB 36.8 MB/s eta 0:00:00m eta 0:00:0136m0:00:01
# Downloading pypdf-4.1.0-py3-none-any.whl (286 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.1/286.1 kB 34.2 MB/s eta 0:00:00
# Downloading llama_index_agent_openai-0.1.5-py3-none-any.whl (12 kB)
# Downloading llama_index_cli-0.1.8-py3-none-any.whl (25 kB)
# Downloading llama_index_core-0.10.18.post1-py3-none-any.whl (15.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 61.7 MB/s eta 0:00:00m eta 0:00:010:0101
# Downloading llama_index_embeddings_openai-0.1.6-py3-none-any.whl (6.0 kB)
# Downloading llama_index_indices_managed_llama_cloud-0.1.3-py3-none-any.whl (6.6 kB)
# Downloading llama_index_legacy-0.9.48-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 66.6 MB/s eta 0:00:00
# Downloading llama_index_llms_openai-0.1.7-py3-none-any.whl (9.3 kB)
# Downloading llama_index_multi_modal_llms_openai-0.1.4-py3-none-any.whl (5.8 kB)
# Downloading llama_index_program_openai-0.1.4-py3-none-any.whl (4.1 kB)
# Downloading llama_index_question_gen_openai-0.1.3-py3-none-any.whl (2.9 kB)
# Downloading llama_index_readers_file-0.1.9-py3-none-any.whl (35 kB)
# Downloading llama_index_readers_llama_parse-0.1.3-py3-none-any.whl (2.5 kB)
# Downloading tqdm-4.66.2-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 11.0 MB/s eta 0:00:00
# Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.9/147.9 kB 22.1 MB/s eta 0:00:00
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Downloading dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Downloading llama_index_vector_stores_chroma-0.1.6-py3-none-any.whl (4.7 kB)
# Downloading llama_parse-0.3.8-py3-none-any.whl (6.7 kB)
# Downloading llamaindex_py_client-0.1.13-py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 12.9 MB/s eta 0:00:00
# Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 70.2 MB/s eta 0:00:00
# Downloading openai-1.13.3-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.4/227.4 kB 29.2 MB/s eta 0:00:00
# Downloading PyMuPDF-1.23.26-cp310-none-manylinux2014_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 71.4 MB/s eta 0:00:0031m87.5 MB/s eta 0:00:01
# Downloading PyMuPDFb-1.23.22-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (30.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.6/30.6 MB 57.4 MB/s eta 0:00:00m eta 0:00:010:0101
# Downloading SQLAlchemy-2.0.28-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 66.2 MB/s eta 0:00:0031m89.4 MB/s eta 0:00:01
# Downloading striprtf-0.0.26-py3-none-any.whl (6.9 kB)
# Downloading chromadb-0.4.24-py3-none-any.whl (525 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 525.5/525.5 kB 45.9 MB/s eta 0:00:00
# Downloading chroma_hnswlib-0.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 65.3 MB/s eta 0:00:00m eta 0:00:01
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading greenlet-3.0.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (616 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 616.0/616.0 kB 54.5 MB/s eta 0:00:00
# Downloading bcrypt-4.1.2-cp39-abi3-manylinux_2_28_x86_64.whl (698 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 698.9/698.9 kB 51.7 MB/s eta 0:00:00
# Downloading build-1.1.1-py3-none-any.whl (19 kB)
# Downloading kubernetes-29.0.0-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 66.7 MB/s eta 0:00:00
# Downloading mmh3-4.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 10.6 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.23.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 7.6 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.23.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.23.0-py3-none-any.whl (17 kB)
# Downloading opentelemetry_proto-1.23.0-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 6.7 MB/s eta 0:00:00
# Downloading opentelemetry_instrumentation_fastapi-0.44b0-py3-none-any.whl (11 kB)
# Downloading opentelemetry_instrumentation-0.44b0-py3-none-any.whl (28 kB)
# Downloading opentelemetry_instrumentation_asgi-0.44b0-py3-none-any.whl (14 kB)
# Downloading opentelemetry_semantic_conventions-0.44b0-py3-none-any.whl (36 kB)
# Downloading opentelemetry_util_http-0.44b0-py3-none-any.whl (6.9 kB)
# Downloading opentelemetry_sdk-1.23.0-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.7/105.7 kB 14.7 MB/s eta 0:00:00
# Downloading pulsar_client-3.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 43.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading importlib_resources-6.1.3-py3-none-any.whl (34 kB)
# Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 43.7 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 70.3 MB/s eta 0:00:0031m89.6 MB/s eta 0:00:01
# Downloading watchfiles-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 59.9 MB/s eta 0:00:00
# Downloading pyproject_hooks-1.0.0-py3-none-any.whl (9.3 kB)
# Downloading asgiref-3.7.2-py3-none-any.whl (24 kB)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53724 sha256=4c3af48e419067d2d4b0306ba4a3d8dbe0a5e1d18f61dc0e09f290aab6e58235
#   Stored in directory: /home/edoardo/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built pypika
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: striprtf, pypika, mmh3, dirtyjson, uvloop, tqdm, python-dotenv, pyproject_hooks, pypdf, PyMuPDFb, pulsar-client, opentelemetry-util-http, opentelemetry-semantic-conventions, opentelemetry-proto, networkx, importlib-resources, httptools, greenlet, distro, deprecated, chroma-hnswlib, beautifulsoup4, bcrypt, asgiref, watchfiles, SQLAlchemy, pymupdf, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, build, bs4, opentelemetry-sdk, opentelemetry-instrumentation, kubernetes, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, openai, llamaindex-py-client, opentelemetry-instrumentation-fastapi, llama-index-legacy, llama-index-core, llama-parse, llama-index-readers-file, llama-index-llms-openai, llama-index-indices-managed-llama-cloud, llama-index-embeddings-openai, chromadb, llama-index-vector-stores-chroma, llama-index-readers-llama-parse, llama-index-multi-modal-llms-openai, llama-index-agent-openai, llama-index-program-openai, llama-index-cli, llama-index-question-gen-openai, llama-index, bitsandbytes
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.65.0
#     Uninstalling tqdm-4.65.0:
#       Successfully uninstalled tqdm-4.65.0
#   Attempting uninstall: networkx
#     Found existing installation: networkx 2.8.8
#     Uninstalling networkx-2.8.8:
#       Successfully uninstalled networkx-2.8.8
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.12.2
#     Uninstalling beautifulsoup4-4.12.2:
#       Successfully uninstalled beautifulsoup4-4.12.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tts 0.22.0 requires librosa>=0.10.0, but you have librosa 0.9.1 which is incompatible.
# tts 0.22.0 requires numpy==1.22.0; python_version <= "3.10", but you have numpy 1.23.0 which is incompatible.
# tts 0.22.0 requires scipy>=1.11.2, but you have scipy 1.11.1 which is incompatible.
# tts 0.22.0 requires torch>=2.1, but you have torch 2.0.1+cu118 which is incompatible.
# audiolm-pytorch 2.0.7 requires torch>=2.1, but you have torch 2.0.1+cu118 which is incompatible.
# farm-haystack 1.21.2 requires transformers==4.32.1, but you have transformers 4.38.2 which is incompatible.
# gruut 2.2.3 requires networkx<3.0.0,>=2.5.0, but you have networkx 3.2.1 which is incompatible.
# Successfully installed PyMuPDFb-1.23.22 SQLAlchemy-2.0.28 asgiref-3.7.2 bcrypt-4.1.2 beautifulsoup4-4.12.3 bitsandbytes-0.43.0 bs4-0.0.2 build-1.1.1 chroma-hnswlib-0.7.3 chromadb-0.4.24 deprecated-1.2.14 dirtyjson-1.0.8 distro-1.9.0 greenlet-3.0.3 httptools-0.6.1 importlib-resources-6.1.3 kubernetes-29.0.0 llama-index-0.10.18 llama-index-agent-openai-0.1.5 llama-index-cli-0.1.8 llama-index-core-0.10.18.post1 llama-index-embeddings-openai-0.1.6 llama-index-indices-managed-llama-cloud-0.1.3 llama-index-legacy-0.9.48 llama-index-llms-openai-0.1.7 llama-index-multi-modal-llms-openai-0.1.4 llama-index-program-openai-0.1.4 llama-index-question-gen-openai-0.1.3 llama-index-readers-file-0.1.9 llama-index-readers-llama-parse-0.1.3 llama-index-vector-stores-chroma-0.1.6 llama-parse-0.3.8 llamaindex-py-client-0.1.13 mmh3-4.1.0 networkx-3.2.1 openai-1.13.3 opentelemetry-api-1.23.0 opentelemetry-exporter-otlp-proto-common-1.23.0 opentelemetry-exporter-otlp-proto-grpc-1.23.0 opentelemetry-instrumentation-0.44b0 opentelemetry-instrumentation-asgi-0.44b0 opentelemetry-instrumentation-fastapi-0.44b0 opentelemetry-proto-1.23.0 opentelemetry-sdk-1.23.0 opentelemetry-semantic-conventions-0.44b0 opentelemetry-util-http-0.44b0 pulsar-client-3.4.0 pymupdf-1.23.26 pypdf-4.1.0 pypika-0.48.9 pyproject_hooks-1.0.0 python-dotenv-1.0.1 striprtf-0.0.26 tqdm-4.66.2 uvloop-0.19.0 watchfiles-0.21.0

# %%
# !pip install llama-index-llms-huggingface

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
import torch
from transformers import BitsAndBytesConfig
from llama_index.core.prompts.base import PromptTemplate
from llama_index.llms.huggingface import HuggingFaceLLM
from llama_index.core import ServiceContext
from llama_index.core.response.notebook_utils import display_response

# %%
quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True,
)

# %%
def messages_to_prompt(messages):
  prompt = ""
  for message in messages:
    if message.role == 'system':
      prompt += f"<|system|>\n{message.content}\n"
    elif message.role == 'user':
      prompt += f"<|user|>\n{message.content}\n"
    elif message.role == 'assistant':
      prompt += f"<|assistant|>\n{message.content}\n"
# ensure we start with a system prompt, insert blank if needed
  if not prompt.startswith("<|system|>\n"):
    prompt = "<|system|>\n\n" + prompt

  # add final assistant prompt
  prompt = prompt + "<|assistant|>\n"

  return prompt

# %%
from huggingface_hub import login
import os

token = os.getenv('HUGGING_FACE_TOKEN')
login(token = token)
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# https://medium.com/@yakkalakartheek/retrieval-augmented-generation-rag-using-open-source-llms-805184b0fe58

# %%
llm = HuggingFaceLLM(
    model_name="meta-llama/Llama-2-7b-chat-hf",
    tokenizer_name="meta-llama/Llama-2-7b-chat-hf",
    query_wrapper_prompt=PromptTemplate("<|system|>\n\n<|user|>\n{query_str}\n<|assistant|>\n"),
    context_window=3900,
    max_new_tokens=256,
    model_kwargs={"quantization_config": quantization_config},
    # tokenizer_kwargs={},
    generate_kwargs={"temperature": 0.3, "top_k": 50, "top_p": 0.95},
    messages_to_prompt=messages_to_prompt,
    device_map="auto",

)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/devel/env/lib/python3.10/site-packages/huggingface_hub/utils/_errors.py:304, in hf_raise_for_status(response, endpoint_name)
#     302     raise GatedRepoError(message, response) from e
# --> 304 elif error_code == "RepoNotFound" or (
#     305     response.status_code == 401
#     306     and response.request is not None
#     307     and response.request.url is not None
#     308     and REPO_API_REGEX.search(response.request.url) is not None
#     309 ):
#     310     # 401 is misleading as it is returned for:
#     311     #    - private and gated repos if user is not authenticated
#     312     #    - missing repos
#     313     # => for now, we process them as `RepoNotFound` anyway.
#     314     # See https://gist.github.com/Wauplin/46c27ad266b15998ce56a6603796f0b9
#     315     message = (
#     316         f"{response.status_code} Client Error."
#     317         + "\n\n"
#    (...)
#     321         " make sure you are authenticated."
#     322     )
#
# File ~/devel/env/lib/python3.10/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://huggingface.co/meta-llama/Llama-2-7b-chat-hf/resolve/main/config.json
#
# The above exception was the direct cause of the following exception:
#
# GatedRepoError                            Traceback (most recent call last)
# File ~/devel/env/lib/python3.10/site-packages/transformers/utils/hub.py:398, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     396 try:
#     397     # Load from URL or cache if already cached
# --> 398     resolved_file = hf_hub_download(
#     399         path_or_repo_id,
#     400         filename,
#     401         subfolder=None if len(subfolder) == 0 else subfolder,
#     402         repo_type=repo_type,
#     403         revision=revision,
#     404         cache_dir=cache_dir,
#     405         user_agent=user_agent,
#     406         force_download=force_download,
#     407         proxies=proxies,
#     408         resume_download=resume_download,
#     409         token=token,
#     410         local_files_only=local_files_only,
#     411     )
#     412 except GatedRepoError as e:
#
# File ~/devel/env/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:118, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     116     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 118 return fn(*args, **kwargs)
#
# File ~/devel/env/lib/python3.10/site-packages/huggingface_hub/file_download.py:1403, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, local_dir_use_symlinks, user_agent, force_download, force_filename, proxies, etag_timeout, resume_download, token, local_files_only, legacy_cache_layout, endpoint)
#    1401         return pointer_path
# -> 1403 # Prevent parallel downloads of the same file with a lock.
#    1404 # etag could be duplicated across repos,
#    1405 lock_path = os.path.join(locks_dir, repo_folder_name(repo_id=repo_id, repo_type=repo_type), f"{etag}.lock")
#
# File ~/devel/env/lib/python3.10/site-packages/huggingface_hub/file_download.py:1261, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, local_dir_use_symlinks, user_agent, force_download, force_filename, proxies, etag_timeout, resume_download, token, local_files_only, legacy_cache_layout, endpoint)
#    1259 if commit_hash is None:
#    1260     raise FileMetadataError(
# -> 1261         "Distant resource does not seem to be on huggingface.co. It is possible that a configuration issue"
#    1262         " prevents you from downloading resources from https://huggingface.co. Please check your firewall"
#    1263         " and proxy settings and make sure your SSL certificates are updated."
#    1264     )
#    1266 # Etag must exist
#
# File ~/devel/env/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:118, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     116     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 118 return fn(*args, **kwargs)
#
# File ~/devel/env/lib/python3.10/site-packages/huggingface_hub/file_download.py:1667, in get_hf_file_metadata(url, token, proxies, timeout, library_name, library_version, user_agent)
#    1663 def _chmod_and_replace(src: str, dst: str) -> None:
#    1664     """Set correct permission before moving a blob from tmp directory to cache dir.
#    1665
#    1666     Do not take into account the `umask` from the process as there is no convenient way
# -> 1667     to get it that is thread-safe.
#    1668
#    1669     See:
#    1670     - About umask: https://docs.python.org/3/library/os.html#os.umask
#    1671     - Thread-safety: https://stackoverflow.com/a/70343066
#    1672     - About solution: https://github.com/huggingface/huggingface_hub/pull/1220#issuecomment-1326211591
#    1673     - Fix issue: https://github.com/huggingface/huggingface_hub/issues/1141
#    1674     - Fix issue: https://github.com/huggingface/huggingface_hub/issues/1215
#    1675     """
#    1676     # Get umask by creating a temporary file in the cached repo folder.
#
# File ~/devel/env/lib/python3.10/site-packages/huggingface_hub/file_download.py:385, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     384 if follow_relative_redirects:
# --> 385     response = _request_wrapper(
#     386         method=method,
#     387         url=url,
#     388         follow_relative_redirects=False,
#     389         **params,
#     390     )
#     392     # If redirection, we redirect only relative paths.
#     393     # This is useful in case of a renamed repository.
#
# File ~/devel/env/lib/python3.10/site-packages/huggingface_hub/file_download.py:409, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     408 response = get_session().request(method=method, url=url, **params)
# --> 409 hf_raise_for_status(response)
#     410 return response
#
# File ~/devel/env/lib/python3.10/site-packages/huggingface_hub/utils/_errors.py:321, in hf_raise_for_status(response, endpoint_name)
#     304 elif error_code == "RepoNotFound" or (
#     305     response.status_code == 401
#     306     and response.request is not None
#    (...)
#     313     # => for now, we process them as `RepoNotFound` anyway.
#     314     # See https://gist.github.com/Wauplin/46c27ad266b15998ce56a6603796f0b9
#     315     message = (
#     316         f"{response.status_code} Client Error."
#     317         + "\n\n"
#     318         + f"Repository Not Found for url: {response.url}."
#     319         + "\nPlease make sure you specified the correct `repo_id` and"
#     320         " `repo_type`.\nIf you are trying to access a private or gated repo,"
# --> 321         " make sure you are authenticated."
#     322     )
#     323     raise RepositoryNotFoundError(message, response) from e
#
# GatedRepoError: 403 Client Error. (Request ID: Root=1-65f06413-7bf2ddde0876f39632cdc802;55e2552e-41df-45dc-8324-d20bd3fe9695)
#
# Cannot access gated repo for url https://huggingface.co/meta-llama/Llama-2-7b-chat-hf/resolve/main/config.json.
# Access to model meta-llama/Llama-2-7b-chat-hf is restricted and you are not in the authorized list. Visit https://huggingface.co/meta-llama/Llama-2-7b-chat-hf to ask for access.
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 llm = HuggingFaceLLM(
#       2     model_name="meta-llama/Llama-2-7b-chat-hf",
#       3     tokenizer_name="meta-llama/Llama-2-7b-chat-hf",
#       4     query_wrapper_prompt=PromptTemplate("<|system|>\n\n<|user|>\n{query_str}\n<|assistant|>\n"),
#       5     context_window=3900,
#       6     max_new_tokens=256,
#       7     model_kwargs={"quantization_config": quantization_config},
#       8     # tokenizer_kwargs={},
#       9     generate_kwargs={"temperature": 0.3, "top_k": 50, "top_p": 0.95},
#      10     messages_to_prompt=messages_to_prompt,
#      11     device_map="auto",
#      12
#      13 )
#
# File ~/devel/env/lib/python3.10/site-packages/llama_index/llms/huggingface/base.py:161, in HuggingFaceLLM.__init__(self, context_window, max_new_tokens, query_wrapper_prompt, tokenizer_name, model_name, model, tokenizer, device_map, stopping_ids, tokenizer_kwargs, tokenizer_outputs_to_remove, model_kwargs, generate_kwargs, is_chat_model, callback_manager, system_prompt, messages_to_prompt, completion_to_prompt, pydantic_program_mode, output_parser)
#     159 """Initialize params."""
#     160 model_kwargs = model_kwargs or {}
# --> 161 self._model = model or AutoModelForCausalLM.from_pretrained(
#     162     model_name, device_map=device_map, **model_kwargs
#     163 )
#     165 # check context_window
#     166 config_dict = self._model.config.to_dict()
#
# File ~/devel/env/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:521, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     518 if kwargs.get("quantization_config", None) is not None:
#     519     _ = kwargs.pop("quantization_config")
# --> 521 config, kwargs = AutoConfig.from_pretrained(
#     522     pretrained_model_name_or_path,
#     523     return_unused_kwargs=True,
#     524     trust_remote_code=trust_remote_code,
#     525     code_revision=code_revision,
#     526     _commit_hash=commit_hash,
#     527     **hub_kwargs,
#     528     **kwargs,
#     529 )
#     531 # if torch_dtype=auto was passed here, ensure to pass it on
#     532 if kwargs_orig.get("torch_dtype", None) == "auto":
#
# File ~/devel/env/lib/python3.10/site-packages/transformers/models/auto/configuration_auto.py:1111, in AutoConfig.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1108 trust_remote_code = kwargs.pop("trust_remote_code", None)
#    1109 code_revision = kwargs.pop("code_revision", None)
# -> 1111 config_dict, unused_kwargs = PretrainedConfig.get_config_dict(pretrained_model_name_or_path, **kwargs)
#    1112 has_remote_code = "auto_map" in config_dict and "AutoConfig" in config_dict["auto_map"]
#    1113 has_local_code = "model_type" in config_dict and config_dict["model_type"] in CONFIG_MAPPING
#
# File ~/devel/env/lib/python3.10/site-packages/transformers/configuration_utils.py:633, in PretrainedConfig.get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     631 original_kwargs = copy.deepcopy(kwargs)
#     632 # Get config dict associated with the base config file
# --> 633 config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#     634 if "_commit_hash" in config_dict:
#     635     original_kwargs["_commit_hash"] = config_dict["_commit_hash"]
#
# File ~/devel/env/lib/python3.10/site-packages/transformers/configuration_utils.py:688, in PretrainedConfig._get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     684 configuration_file = kwargs.pop("_configuration_file", CONFIG_NAME)
#     686 try:
#     687     # Load from local folder or from cache or download from model Hub and cache
# --> 688     resolved_config_file = cached_file(
#     689         pretrained_model_name_or_path,
#     690         configuration_file,
#     691         cache_dir=cache_dir,
#     692         force_download=force_download,
#     693         proxies=proxies,
#     694         resume_download=resume_download,
#     695         local_files_only=local_files_only,
#     696         token=token,
#     697         user_agent=user_agent,
#     698         revision=revision,
#     699         subfolder=subfolder,
#     700         _commit_hash=commit_hash,
#     701     )
#     702     commit_hash = extract_commit_hash(resolved_config_file, commit_hash)
#     703 except EnvironmentError:
#     704     # Raise any environment error raise by `cached_file`. It will have a helpful error message adapted to
#     705     # the original exception.
#
# File ~/devel/env/lib/python3.10/site-packages/transformers/utils/hub.py:416, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     414     if resolved_file is not None or not _raise_exceptions_for_gated_repo:
#     415         return resolved_file
# --> 416     raise EnvironmentError(
#     417         "You are trying to access a gated repo.\nMake sure to have access to it at "
#     418         f"https://huggingface.co/{path_or_repo_id}.\n{str(e)}"
#     419     ) from e
#     420 except RepositoryNotFoundError as e:
#     421     raise EnvironmentError(
#     422         f"{path_or_repo_id} is not a local folder and is not a valid model identifier "
#     423         "listed on 'https://huggingface.co/models'\nIf this is a private repository, make sure to pass a token "
#     424         "having permission to this repo either by logging in with `huggingface-cli login` or by passing "
#     425         "`token=<your_token>`"
#     426     ) from e
#
# OSError: You are trying to access a gated repo.
# Make sure to have access to it at https://huggingface.co/meta-llama/Llama-2-7b-chat-hf.
# 403 Client Error. (Request ID: Root=1-65f06413-7bf2ddde0876f39632cdc802;55e2552e-41df-45dc-8324-d20bd3fe9695)
#
# Cannot access gated repo for url https://huggingface.co/meta-llama/Llama-2-7b-chat-hf/resolve/main/config.json.
# Access to model meta-llama/Llama-2-7b-chat-hf is restricted and you are not in the authorized list. Visit https://huggingface.co/meta-llama/Llama-2-7b-chat-hf to ask for access.
